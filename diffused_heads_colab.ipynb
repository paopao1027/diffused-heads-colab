# %% [markdown]
# <a href="https://colab.research.google.com/github/hoalarious/diffused-heads-colab/blob/main/diffused_heads_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hoalarious/diffused-heads-colab.git
# %cd diffused-heads-colab
# !pip install -r requirements.txt  &> /dev/null
# !pip install elevenlabs  &> /dev/null
# !apt -y install -qq aria2 &> /dev/null

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hoalarious/diffused-heads-colab/resolve/main/audio_encoder.pt -d checkpoints -o audio_encoder.pt  &> /dev/null
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hoalarious/diffused-heads-colab/resolve/main/crema_script.pt -d checkpoints -o crema_script.pt  &> /dev/null
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hoalarious/diffused-heads-colab/resolve/main/video_s1_1.mp4 -o video.mp4  &> /dev/null
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hoalarious/diffused-heads-colab/resolve/main/sample_audio_s1_1.wav -o diffused_sample.wav  &> /dev/null

# %%
# @title Text to speak via 11Labs API
text_to_speak = "\"Hi! My name is Bella, nice to meet you!\"" # @param {type:"string"}
from elevenlabs import generate, play, save
from IPython.display import Audio, display

audio = generate(
  text=text_to_speak,
  voice="Bella",
  model="eleven_monolingual_v1"
)

# !rm diffused_sample.wav

save(
    audio= audio,               # Audio bytes (returned by generate)
    filename= "diffused_sample2.wav"               # Filename to save audio to (e.g. "audio.wav")
)
# !ffmpeg -i diffused_sample2.wav -ac 1 -ar 16000 diffused_sample.wav -y
display(Audio("diffused_sample2.wav"))
display(Audio("diffused_sample.wav", autoplay=True))

# %%
# !python sample.py hydra.job.chdir=False
# Out:
# ['config_crema.yaml', 'intro.gif', '.gitignore', '__pycache__', 'sample.py', '.git', 'video.mp4', 'diffused_heads_colab.ipynb', 'checkpoints', 'utils.py', 'requirements.txt', 'outputs', 'diffused_sample2.wav', 'LICENSE', 'diffusion.py', 'diffused_sample.wav', 'environment.yml', 'README.md']
# Loading model...
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at ../aten/src/ATen/native/cudnn/RNN.cpp:982.)
#   return forward_call(*args, **kwargs)
# Sampling: 100% 58/58 [20:32<00:00, 21.25s/it]
# Results saved at outputs/output_video.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/diffused-heads-colab/outputs/output_video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
